# %%
# !python -m pip install matplotlib numpy scikit-learn opencv-python tensorflow[and-cuda] pandas
# Out:
# Requirement already satisfied: matplotlib in e:\aditya\python\lib\site-packages (3.7.5)
# Requirement already satisfied: numpy in e:\aditya\python\lib\site-packages (1.24.3)
# Requirement already satisfied: scikit-learn in e:\aditya\python\lib\site-packages (1.3.2)
# Requirement already satisfied: opencv-python in e:\aditya\python\lib\site-packages (4.9.0.80)
# Requirement already satisfied: pandas in e:\aditya\python\lib\site-packages (2.0.3)
# Requirement already satisfied: tensorflow[and-cuda] in e:\aditya\python\lib\site-packages (2.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in e:\aditya\python\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in e:\aditya\python\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\aditya\python\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\aditya\python\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\adity\appdata\roaming\python\python38\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in e:\aditya\python\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\aditya\python\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\adity\appdata\roaming\python\python38\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in e:\aditya\python\lib\site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: scipy>=1.5.0 in e:\aditya\python\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in e:\aditya\python\lib\site-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\aditya\python\lib\site-packages (from scikit-learn) (3.4.0)
# Requirement already satisfied: tensorflow-intel==2.13.0 in e:\aditya\python\lib\site-packages (from tensorflow[and-cuda]) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in e:\aditya\python\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow[and-cuda]) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in e:\aditya\python\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow[and-cuda]) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in e:\aditya\python\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow[and-cuda]) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in e:\aditya\python\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow[and-cuda]) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in e:\aditya\python\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow[and-cuda]) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in e:\aditya\python\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow[and-cuda]) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in e:\aditya\python\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow[and-cuda]) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in e:\aditya\python\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow[and-cuda]) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in e:\aditya\python\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow[and-cuda]) (4.25.3)
# Requirement already satisfied: setuptools in e:\aditya\python\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow[and-cuda]) (47.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\adity\appdata\roaming\python\python38\site-packages (from tensorflow-intel==2.13.0->tensorflow[and-cuda]) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in e:\aditya\python\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow[and-cuda]) (2.4.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in e:\aditya\python\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow[and-cuda]) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in e:\aditya\python\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow[and-cuda]) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in e:\aditya\python\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow[and-cuda]) (1.62.1)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in e:\aditya\python\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow[and-cuda]) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in e:\aditya\python\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow[and-cuda]) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in e:\aditya\python\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow[and-cuda]) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in e:\aditya\python\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow[and-cuda]) (0.31.0)
# Requirement already satisfied: pytz>=2020.1 in e:\aditya\python\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in e:\aditya\python\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\adity\appdata\roaming\python\python38\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in e:\aditya\python\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow[and-cuda]) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in e:\aditya\python\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow[and-cuda]) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in e:\aditya\python\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow[and-cuda]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in e:\aditya\python\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow[and-cuda]) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in e:\aditya\python\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow[and-cuda]) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in e:\aditya\python\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow[and-cuda]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in e:\aditya\python\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow[and-cuda]) (1.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in e:\aditya\python\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow[and-cuda]) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in e:\aditya\python\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow[and-cuda]) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in e:\aditya\python\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow[and-cuda]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in e:\aditya\python\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow[and-cuda]) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\adity\appdata\roaming\python\python38\site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow[and-cuda]) (6.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\aditya\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow[and-cuda]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\aditya\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow[and-cuda]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\aditya\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow[and-cuda]) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in e:\aditya\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow[and-cuda]) (2024.2.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in e:\aditya\python\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow[and-cuda]) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in e:\aditya\python\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow[and-cuda]) (3.2.2)
# WARNING: tensorflow 2.13.0 does not provide the extra 'and-cuda'

# %% [markdown]
# ## Hyper-parameter Initialization

# %%
sequence_length = 20
spectrogram_height = 217
spectrogram_width = 50
latent_dim = 128
num_attention_heads = 4
num_classes = 10
batch_size = 32

# %% [markdown]
# ## Model Definitions

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from tensorflow.keras.callbacks import ReduceLROnPlateau
from itertools import product
import pandas as pd

def create_cnn_model():
    model = tf.keras.Sequential()
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(spectrogram_height, spectrogram_width, 1), kernel_regularizer=regularizers.l2(0.01)))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.005)))
    model.add(layers.Flatten())
    model.add(layers.Dense(latent_dim, activation='relu', kernel_regularizer=regularizers.l2(0.005)))
    return model


def create_attention_model(sequence_length, latent_dim, num_attention_heads):
    inputs = tf.keras.Input(shape=(sequence_length, latent_dim))
    attention_output, attention_scores = layers.MultiHeadAttention(num_heads=num_attention_heads, key_dim=latent_dim)(inputs, inputs, return_attention_scores=True)
    attention_output = layers.LayerNormalization()(attention_output)
    # Multiply the attention output by the input to get the final representation
    attention_output = layers.Multiply()([attention_output, inputs])
    # attention_output is now of shape (batch_size, sequence_length, latent_dim)
    # Now do a global average pooling to get the final representation of the sequence
    pooled_output = layers.GlobalAveragePooling1D()(attention_output)
    return tf.keras.models.Model(inputs, [pooled_output, attention_scores], name="attention_model")


def create_classification_model(num_classes, latent_size=128, sequence_length=20, num_heads=4):
    sequence_input = layers.Input(shape=(sequence_length, latent_size))

    # Attention layer
    attention_model = create_attention_model(latent_dim=latent_size, sequence_length=sequence_length, num_attention_heads=num_heads)
    attention_output, attention_scores = attention_model(sequence_input)

    # Classification head
    classification_output = layers.Dense(num_classes, activation='softmax')(attention_output)

    return tf.keras.models.Model(sequence_input, [classification_output, attention_scores], name="classification_model")



def create_model(sequence_length, spectrogram_height, spectrogram_width, latent_dim, num_classes = 10, num_attention_heads = 4):
    cnn_model = create_cnn_model()
    
    
    inputs = tf.keras.Input(shape=(sequence_length, spectrogram_height, spectrogram_width, 1))
    token_embeddings = layers.TimeDistributed(cnn_model)(inputs)

    classification_model = create_classification_model(num_classes, latent_size=latent_dim, sequence_length=sequence_length, num_heads=num_attention_heads)
    classification_output, attention_scores = classification_model(token_embeddings)
    
    # Return both classification output and attention weights
    return tf.keras.models.Model(inputs, [classification_output, attention_scores])

import numpy as np
def train(X_train, y_train, X_val, y_val, epochs=25, batch_size=32):
    full_model = create_model(sequence_length, spectrogram_height, spectrogram_width, latent_dim, num_classes, num_attention_heads)
    classification_output, attention_scores = full_model.predict(X_val)
    model = tf.keras.models.Model(inputs=full_model.input, outputs=full_model.output[0])
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)

    # Train the model on the classification output
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=epochs, batch_size=batch_size, callbacks=[reduce_lr])

    classification_output, attention_scores = full_model.predict(X_val)
    mean_attention_scores = np.mean(attention_scores, axis=1)
    most_important_tokens = np.argmax(mean_attention_scores, axis=1)
    
    return model, most_important_tokens, mean_attention_scores

# %% [markdown]
# ## Extracting Data

# %%
import os
import cv2
import numpy as np

input_dir = 'E:\\Aditya\\IIT_Hyderabad\\Assignments\\Deep Learning\\Project\\Data\\images_cropped_vertical'


X_train = []
y_train = []

for label, genre_folder in enumerate(os.listdir(input_dir)):
    genre_path = os.path.join(input_dir, genre_folder)
    if not os.path.isdir(genre_path):
        continue

    genre_x = []
    genre_y = []
    for number, filename in enumerate(os.listdir(genre_path)):
        img_path = os.path.join(genre_path, filename)
        img = cv2.imread(img_path)
        if img is None:
            continue
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img_resized = cv2.resize(img_gray, (spectrogram_width, spectrogram_height))

        genre_x.append(img_resized)
        genre_y.append(label)
        if ((number + 1)%20 == 0):
            X_train.append(genre_x)
            genre_x = []
            genre_y = []
            y_train.append(label)


# Convert X_train and y_train to numpy arrays
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
# Shuffle X_train and y_train
shuffle_indices = np.arange(X_train.shape[0])
np.random.shuffle(shuffle_indices)
X_train = X_train[shuffle_indices]
y_train = y_train[shuffle_indices]


# Check the shape of X_train and y_train
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (999, 20, 217, 50)
# y_train shape: (999,)

# %%
import os
import numpy as np

# Create a new directory within the Data directory
train_data = 'E:\\Aditya\\IIT_Hyderabad\\Assignments\\Deep Learning\\Project\\Data\\train_data'
os.makedirs(train_data, exist_ok=True)

# Save X_train and y_train as files in the new directory
np.save(os.path.join(train_data, 'X_train.npy'), X_train)
np.save(os.path.join(train_data, 'y_train.npy'), y_train)

# %% [markdown]
# ## Training

# %%
best_val_accuracy = 0
best_model_weights = []
best_initial_weights = []

for train_index, val_index in StratifiedKFold(n_splits=6).split(X_train, y_train):
    X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

    
    # Train the model on the fold, only on the classification output of the model
    model, most_important_tokens, mean_average_scores = train(X_train_fold, y_train_fold, X_val_fold, y_val_fold)
    
    # Evaluate the model (classification output)
    val_loss, val_accuracy = model.evaluate(X_val_fold, y_val_fold)
    
    # Keep track of the best validation accuracy and corresponding weights
    if val_accuracy > best_val_accuracy:
        best_val_accuracy = val_accuracy
        best_model_weights = model.get_weights()
    
    # Save the best model weights
    model.save_weights('best_model_weights.h5')

print("Max validation accuracy using cross-validation on the best model:", best_val_accuracy)
# Out:
# 6/6 [==============================] - 5s 699ms/step
# Epoch 1/25
# 26/26 [==============================] - 111s 4s/step - loss: 13.2261 - accuracy: 0.1214 - val_loss: 4.1683 - val_accuracy: 0.2036 - lr: 0.0010
# Epoch 2/25
# 26/26 [==============================] - 102s 4s/step - loss: 3.8350 - accuracy: 0.2933 - val_loss: 3.3035 - val_accuracy: 0.4431 - lr: 0.0010
# Epoch 3/25
# 26/26 [==============================] - 96s 4s/step - loss: 3.0622 - accuracy: 0.5493 - val_loss: 3.2343 - val_accuracy: 0.4371 - lr: 0.0010
# Epoch 4/25
# 26/26 [==============================] - 96s 4s/step - loss: 2.5801 - accuracy: 0.6779 - val_loss: 2.9847 - val_accuracy: 0.5329 - lr: 0.0010
# Epoch 5/25
# 26/26 [==============================] - 97s 4s/step - loss: 2.2748 - accuracy: 0.7644 - val_loss: 2.8361 - val_accuracy: 0.5868 - lr: 0.0010
# Epoch 6/25
# 26/26 [==============================] - 96s 4s/step - loss: 2.0664 - accuracy: 0.8089 - val_loss: 2.9513 - val_accuracy: 0.5808 - lr: 0.0010
# Epoch 7/25
# 26/26 [==============================] - 96s 4s/step - loss: 2.0009 - accuracy: 0.8161 - val_loss: 2.8084 - val_accuracy: 0.5808 - lr: 0.0010
# Epoch 8/25
# 26/26 [==============================] - 97s 4s/step - loss: 1.7475 - accuracy: 0.8822 - val_loss: 2.9718 - val_accuracy: 0.6287 - lr: 0.0010
# Epoch 9/25
# 26/26 [==============================] - 96s 4s/step - loss: 1.6495 - accuracy: 0.9099 - val_loss: 2.7859 - val_accuracy: 0.6108 - lr: 0.0010
# Epoch 10/25
# 26/26 [==============================] - 98s 4s/step - loss: 1.4977 - accuracy: 0.9387 - val_loss: 2.9105 - val_accuracy: 0.6048 - lr: 0.0010
# Epoch 11/25
# 26/26 [==============================] - 96s 4s/step - loss: 1.4261 - accuracy: 0.9423 - val_loss: 3.4083 - val_accuracy: 0.6048 - lr: 0.0010
# Epoch 12/25
# 26/26 [==============================] - 95s 4s/step - loss: 1.4247 - accuracy: 0.9363 - val_loss: 3.2601 - val_accuracy: 0.5629 - lr: 0.0010
# Epoch 13/25
# 26/26 [==============================] - 95s 4s/step - loss: 1.2800 - accuracy: 0.9808 - val_loss: 2.9688 - val_accuracy: 0.5749 - lr: 0.0010
# Epoch 14/25
# 26/26 [==============================] - 96s 4s/step - loss: 1.1967 - accuracy: 0.9904 - val_loss: 3.2236 - val_accuracy: 0.5808 - lr: 0.0010
# Epoch 15/25
# 26/26 [==============================] - 97s 4s/step - loss: 1.1497 - accuracy: 0.9952 - val_loss: 3.1638 - val_accuracy: 0.6467 - lr: 2.0000e-04
# Epoch 16/25
# 26/26 [==============================] - 96s 4s/step - loss: 1.1219 - accuracy: 0.9988 - val_loss: 3.1696 - val_accuracy: 0.6407 - lr: 2.0000e-04
# Epoch 17/25
# 26/26 [==============================] - 96s 4s/step - loss: 1.1059 - accuracy: 0.9988 - val_loss: 3.1847 - val_accuracy: 0.6467 - lr: 2.0000e-04
# Epoch 18/25
# 26/26 [==============================] - 95s 4s/step - loss: 1.0911 - accuracy: 0.9988 - val_loss: 3.1757 - val_accuracy: 0.6467 - lr: 2.0000e-04
# Epoch 19/25
# 26/26 [==============================] - 94s 4s/step - loss: 1.0792 - accuracy: 0.9976 - val_loss: 3.1763 - val_accuracy: 0.6527 - lr: 2.0000e-04
# Epoch 20/25
# 26/26 [==============================] - 94s 4s/step - loss: 1.0687 - accuracy: 0.9988 - val_loss: 3.1735 - val_accuracy: 0.6587 - lr: 4.0000e-05
# Epoch 21/25
# 26/26 [==============================] - 94s 4s/step - loss: 1.0662 - accuracy: 0.9988 - val_loss: 3.1771 - val_accuracy: 0.6527 - lr: 4.0000e-05
# Epoch 22/25
# 26/26 [==============================] - 96s 4s/step - loss: 1.0636 - accuracy: 0.9976 - val_loss: 3.1833 - val_accuracy: 0.6467 - lr: 4.0000e-05
# Epoch 23/25
# 26/26 [==============================] - 93s 4s/step - loss: 1.0606 - accuracy: 0.9976 - val_loss: 3.1790 - val_accuracy: 0.6587 - lr: 4.0000e-05
# Epoch 24/25
# 26/26 [==============================] - 95s 4s/step - loss: 1.0572 - accuracy: 0.9988 - val_loss: 3.1829 - val_accuracy: 0.6527 - lr: 4.0000e-05
# Epoch 25/25
# 26/26 [==============================] - 94s 4s/step - loss: 1.0554 - accuracy: 0.9988 - val_loss: 3.1819 - val_accuracy: 0.6527 - lr: 8.0000e-06
# 6/6 [==============================] - 4s 682ms/step
# 6/6 [==============================] - 4s 696ms/step - loss: 3.1819 - accuracy: 0.6527
# 6/6 [==============================] - 5s 685ms/step
# Epoch 1/25
# 26/26 [==============================] - 95s 4s/step - loss: 16.1357 - accuracy: 0.1274 - val_loss: 4.3115 - val_accuracy: 0.1737 - lr: 0.0010
# Epoch 2/25
# 26/26 [==============================] - 90s 3s/step - loss: 4.0728 - accuracy: 0.2404 - val_loss: 3.9580 - val_accuracy: 0.3054 - lr: 0.0010
# Epoch 3/25
# 26/26 [==============================] - 91s 3s/step - loss: 3.7805 - accuracy: 0.3990 - val_loss: 3.5897 - val_accuracy: 0.4431 - lr: 0.0010
# Epoch 4/25
# 26/26 [==============================] - 92s 4s/step - loss: 3.2633 - accuracy: 0.4916 - val_loss: 3.4124 - val_accuracy: 0.5210 - lr: 0.0010
# Epoch 5/25
# 26/26 [==============================] - 90s 3s/step - loss: 2.8658 - accuracy: 0.5950 - val_loss: 3.6074 - val_accuracy: 0.4731 - lr: 0.0010
# Epoch 6/25
# 26/26 [==============================] - 91s 4s/step - loss: 2.5865 - accuracy: 0.6875 - val_loss: 3.2884 - val_accuracy: 0.5030 - lr: 0.0010
# Epoch 7/25
# 26/26 [==============================] - 90s 3s/step - loss: 2.2844 - accuracy: 0.7668 - val_loss: 3.3887 - val_accuracy: 0.5389 - lr: 0.0010
# Epoch 8/25
# 26/26 [==============================] - 92s 4s/step - loss: 2.1049 - accuracy: 0.8173 - val_loss: 3.3245 - val_accuracy: 0.5389 - lr: 0.0010
# Epoch 9/25
# 26/26 [==============================] - 98s 4s/step - loss: 1.9351 - accuracy: 0.8654 - val_loss: 3.5088 - val_accuracy: 0.5928 - lr: 0.0010
# Epoch 10/25
# 26/26 [==============================] - 106s 4s/step - loss: 1.8288 - accuracy: 0.9014 - val_loss: 3.3456 - val_accuracy: 0.5808 - lr: 0.0010
# Epoch 11/25
# 26/26 [==============================] - 95s 4s/step - loss: 1.7400 - accuracy: 0.9267 - val_loss: 3.2960 - val_accuracy: 0.5808 - lr: 0.0010
# Epoch 12/25
# 26/26 [==============================] - 93s 4s/step - loss: 1.5660 - accuracy: 0.9820 - val_loss: 3.4570 - val_accuracy: 0.6168 - lr: 2.0000e-04
# Epoch 13/25
# 26/26 [==============================] - 93s 4s/step - loss: 1.5047 - accuracy: 0.9880 - val_loss: 3.4995 - val_accuracy: 0.6048 - lr: 2.0000e-04
# Epoch 14/25
# 26/26 [==============================] - 92s 4s/step - loss: 1.4730 - accuracy: 0.9904 - val_loss: 3.5788 - val_accuracy: 0.5988 - lr: 2.0000e-04
# Epoch 15/25
# 26/26 [==============================] - 91s 4s/step - loss: 1.4442 - accuracy: 0.9952 - val_loss: 3.6188 - val_accuracy: 0.6347 - lr: 2.0000e-04
# Epoch 16/25
# 26/26 [==============================] - 91s 4s/step - loss: 1.4201 - accuracy: 0.9976 - val_loss: 3.6653 - val_accuracy: 0.6168 - lr: 2.0000e-04
# Epoch 17/25
# 26/26 [==============================] - 92s 4s/step - loss: 1.4052 - accuracy: 0.9964 - val_loss: 3.6763 - val_accuracy: 0.6168 - lr: 4.0000e-05
# Epoch 18/25
# 26/26 [==============================] - 92s 4s/step - loss: 1.4006 - accuracy: 0.9988 - val_loss: 3.6878 - val_accuracy: 0.6168 - lr: 4.0000e-05
# Epoch 19/25
# 26/26 [==============================] - 93s 4s/step - loss: 1.3966 - accuracy: 0.9988 - val_loss: 3.6908 - val_accuracy: 0.6228 - lr: 4.0000e-05
# Epoch 20/25
# 26/26 [==============================] - 92s 4s/step - loss: 1.3926 - accuracy: 0.9988 - val_loss: 3.7000 - val_accuracy: 0.6228 - lr: 4.0000e-05
# Epoch 21/25
# 26/26 [==============================] - 92s 4s/step - loss: 1.3881 - accuracy: 0.9988 - val_loss: 3.7076 - val_accuracy: 0.6228 - lr: 4.0000e-05
# Epoch 22/25
# 26/26 [==============================] - 91s 4s/step - loss: 1.3853 - accuracy: 0.9988 - val_loss: 3.7088 - val_accuracy: 0.6228 - lr: 8.0000e-06
# Epoch 23/25
# 26/26 [==============================] - 92s 4s/step - loss: 1.3845 - accuracy: 0.9988 - val_loss: 3.7105 - val_accuracy: 0.6228 - lr: 8.0000e-06
# Epoch 24/25
# 26/26 [==============================] - 92s 4s/step - loss: 1.3835 - accuracy: 0.9988 - val_loss: 3.7120 - val_accuracy: 0.6228 - lr: 8.0000e-06
# Epoch 25/25
# 26/26 [==============================] - 92s 4s/step - loss: 1.3826 - accuracy: 0.9988 - val_loss: 3.7143 - val_accuracy: 0.6287 - lr: 8.0000e-06
# 6/6 [==============================] - 4s 680ms/step
# 6/6 [==============================] - 4s 705ms/step - loss: 3.7143 - accuracy: 0.6287
# 6/6 [==============================] - 5s 749ms/step
# Epoch 1/25
# 26/26 [==============================] - 96s 4s/step - loss: 17.6934 - accuracy: 0.1298 - val_loss: 4.2988 - val_accuracy: 0.2635 - lr: 0.0010
# Epoch 2/25
# 26/26 [==============================] - 92s 4s/step - loss: 3.9704 - accuracy: 0.3149 - val_loss: 3.6109 - val_accuracy: 0.3892 - lr: 0.0010
# Epoch 3/25
# 26/26 [==============================] - 93s 4s/step - loss: 3.2719 - accuracy: 0.5012 - val_loss: 3.4095 - val_accuracy: 0.4671 - lr: 0.0010
# Epoch 4/25
# 26/26 [==============================] - 94s 4s/step - loss: 2.8466 - accuracy: 0.6466 - val_loss: 3.1939 - val_accuracy: 0.4850 - lr: 0.0010
# Epoch 5/25
# 26/26 [==============================] - 93s 4s/step - loss: 2.5286 - accuracy: 0.7055 - val_loss: 2.9957 - val_accuracy: 0.5090 - lr: 0.0010
# Epoch 6/25
# 26/26 [==============================] - 93s 4s/step - loss: 2.2927 - accuracy: 0.7464 - val_loss: 2.8987 - val_accuracy: 0.5269 - lr: 0.0010
# Epoch 7/25
# 26/26 [==============================] - 93s 4s/step - loss: 2.0233 - accuracy: 0.8438 - val_loss: 2.9430 - val_accuracy: 0.5509 - lr: 0.0010
# Epoch 8/25
# 26/26 [==============================] - 93s 4s/step - loss: 2.0982 - accuracy: 0.8041 - val_loss: 2.9648 - val_accuracy: 0.5449 - lr: 0.0010
# Epoch 9/25
# 26/26 [==============================] - 97s 4s/step - loss: 1.7696 - accuracy: 0.8858 - val_loss: 3.1047 - val_accuracy: 0.5509 - lr: 0.0010
# Epoch 10/25
# 26/26 [==============================] - 94s 4s/step - loss: 1.6499 - accuracy: 0.9243 - val_loss: 3.2611 - val_accuracy: 0.5389 - lr: 0.0010
# Epoch 11/25
# 26/26 [==============================] - 94s 4s/step - loss: 1.5718 - accuracy: 0.9255 - val_loss: 3.2505 - val_accuracy: 0.5210 - lr: 0.0010
# Epoch 12/25
# 26/26 [==============================] - 92s 4s/step - loss: 1.4647 - accuracy: 0.9760 - val_loss: 2.8876 - val_accuracy: 0.5988 - lr: 2.0000e-04
# Epoch 13/25
# 26/26 [==============================] - 92s 4s/step - loss: 1.3833 - accuracy: 0.9928 - val_loss: 3.0123 - val_accuracy: 0.5749 - lr: 2.0000e-04
# Epoch 14/25
# 26/26 [==============================] - 93s 4s/step - loss: 1.3494 - accuracy: 0.9964 - val_loss: 3.0167 - val_accuracy: 0.5808 - lr: 2.0000e-04
# Epoch 15/25
# 26/26 [==============================] - 95s 4s/step - loss: 1.3274 - accuracy: 0.9952 - val_loss: 3.0961 - val_accuracy: 0.5808 - lr: 2.0000e-04
# Epoch 16/25
# 26/26 [==============================] - 93s 4s/step - loss: 1.3057 - accuracy: 0.9964 - val_loss: 3.1189 - val_accuracy: 0.5928 - lr: 2.0000e-04
# Epoch 17/25
# 26/26 [==============================] - 92s 4s/step - loss: 1.2866 - accuracy: 0.9988 - val_loss: 3.1440 - val_accuracy: 0.5749 - lr: 2.0000e-04
# Epoch 18/25
# 26/26 [==============================] - 94s 4s/step - loss: 1.2739 - accuracy: 0.9988 - val_loss: 3.1416 - val_accuracy: 0.5808 - lr: 4.0000e-05
# Epoch 19/25
# 26/26 [==============================] - 93s 4s/step - loss: 1.2701 - accuracy: 0.9976 - val_loss: 3.1471 - val_accuracy: 0.5749 - lr: 4.0000e-05
# Epoch 20/25
# 26/26 [==============================] - 92s 4s/step - loss: 1.2666 - accuracy: 0.9976 - val_loss: 3.1534 - val_accuracy: 0.5749 - lr: 4.0000e-05
# Epoch 21/25
# 26/26 [==============================] - 92s 4s/step - loss: 1.2633 - accuracy: 0.9988 - val_loss: 3.1600 - val_accuracy: 0.5629 - lr: 4.0000e-05
# Epoch 22/25
# 26/26 [==============================] - 95s 4s/step - loss: 1.2590 - accuracy: 0.9988 - val_loss: 3.1633 - val_accuracy: 0.5868 - lr: 4.0000e-05
# Epoch 23/25
# 26/26 [==============================] - 93s 4s/step - loss: 1.2566 - accuracy: 0.9988 - val_loss: 3.1642 - val_accuracy: 0.5868 - lr: 8.0000e-06
# Epoch 24/25
# 26/26 [==============================] - 92s 4s/step - loss: 1.2558 - accuracy: 0.9988 - val_loss: 3.1646 - val_accuracy: 0.5928 - lr: 8.0000e-06
# Epoch 25/25
# 26/26 [==============================] - 92s 4s/step - loss: 1.2550 - accuracy: 0.9988 - val_loss: 3.1652 - val_accuracy: 0.5928 - lr: 8.0000e-06
# 6/6 [==============================] - 4s 696ms/step
# 6/6 [==============================] - 4s 678ms/step - loss: 3.1652 - accuracy: 0.5928
# 6/6 [==============================] - 4s 686ms/step
# Epoch 1/25
# 27/27 [==============================] - 96s 3s/step - loss: 12.2133 - accuracy: 0.1573 - val_loss: 3.9930 - val_accuracy: 0.2229 - lr: 0.0010
# Epoch 2/25
# 27/27 [==============================] - 92s 3s/step - loss: 3.6444 - accuracy: 0.3601 - val_loss: 3.2573 - val_accuracy: 0.4157 - lr: 0.0010
# Epoch 3/25
# 27/27 [==============================] - 92s 3s/step - loss: 3.0177 - accuracy: 0.5426 - val_loss: 2.9434 - val_accuracy: 0.5060 - lr: 0.0010
# Epoch 4/25
# 27/27 [==============================] - 91s 3s/step - loss: 2.8432 - accuracy: 0.5462 - val_loss: 2.9116 - val_accuracy: 0.5241 - lr: 0.0010
# Epoch 5/25
# 27/27 [==============================] - 90s 3s/step - loss: 2.3657 - accuracy: 0.6939 - val_loss: 2.7854 - val_accuracy: 0.5723 - lr: 0.0010
# Epoch 6/25
# 27/27 [==============================] - 91s 3s/step - loss: 2.0369 - accuracy: 0.7971 - val_loss: 2.5686 - val_accuracy: 0.5422 - lr: 0.0010
# Epoch 7/25
# 27/27 [==============================] - 91s 3s/step - loss: 1.7922 - accuracy: 0.8523 - val_loss: 2.9347 - val_accuracy: 0.5241 - lr: 0.0010
# Epoch 8/25
# 27/27 [==============================] - 91s 3s/step - loss: 1.6679 - accuracy: 0.8667 - val_loss: 3.2575 - val_accuracy: 0.5060 - lr: 0.0010
# Epoch 9/25
# 27/27 [==============================] - 91s 3s/step - loss: 2.0373 - accuracy: 0.7347 - val_loss: 3.6834 - val_accuracy: 0.5120 - lr: 0.0010
# Epoch 10/25
# 27/27 [==============================] - 91s 3s/step - loss: 1.8574 - accuracy: 0.8103 - val_loss: 2.6495 - val_accuracy: 0.5602 - lr: 0.0010
# Epoch 11/25
# 27/27 [==============================] - 91s 3s/step - loss: 1.4985 - accuracy: 0.9184 - val_loss: 2.8113 - val_accuracy: 0.5783 - lr: 0.0010
# Epoch 12/25
# 27/27 [==============================] - 91s 3s/step - loss: 1.3101 - accuracy: 0.9712 - val_loss: 2.6699 - val_accuracy: 0.6024 - lr: 2.0000e-04
# Epoch 13/25
# 27/27 [==============================] - 91s 3s/step - loss: 1.2653 - accuracy: 0.9808 - val_loss: 2.6922 - val_accuracy: 0.5904 - lr: 2.0000e-04
# Epoch 14/25
# 27/27 [==============================] - 91s 3s/step - loss: 1.2175 - accuracy: 0.9904 - val_loss: 2.7465 - val_accuracy: 0.5783 - lr: 2.0000e-04
# Epoch 15/25
# 27/27 [==============================] - 91s 3s/step - loss: 1.1835 - accuracy: 0.9952 - val_loss: 2.7867 - val_accuracy: 0.5843 - lr: 2.0000e-04
# Epoch 16/25
# 27/27 [==============================] - 91s 3s/step - loss: 1.1571 - accuracy: 0.9952 - val_loss: 2.8704 - val_accuracy: 0.5723 - lr: 2.0000e-04
# Epoch 17/25
# 27/27 [==============================] - 92s 3s/step - loss: 1.1398 - accuracy: 0.9976 - val_loss: 2.8682 - val_accuracy: 0.5723 - lr: 4.0000e-05
# Epoch 18/25
# 27/27 [==============================] - 91s 3s/step - loss: 1.1345 - accuracy: 0.9988 - val_loss: 2.8761 - val_accuracy: 0.5783 - lr: 4.0000e-05
# Epoch 19/25
# 27/27 [==============================] - 91s 3s/step - loss: 1.1301 - accuracy: 0.9988 - val_loss: 2.8879 - val_accuracy: 0.5783 - lr: 4.0000e-05
# Epoch 20/25
# 27/27 [==============================] - 91s 3s/step - loss: 1.1252 - accuracy: 0.9976 - val_loss: 2.9025 - val_accuracy: 0.5783 - lr: 4.0000e-05
# Epoch 21/25
# 27/27 [==============================] - 91s 3s/step - loss: 1.1204 - accuracy: 0.9988 - val_loss: 2.9037 - val_accuracy: 0.5783 - lr: 4.0000e-05
# Epoch 22/25
# 27/27 [==============================] - 92s 3s/step - loss: 1.1171 - accuracy: 0.9988 - val_loss: 2.9066 - val_accuracy: 0.5783 - lr: 8.0000e-06
# Epoch 23/25
# 27/27 [==============================] - 91s 3s/step - loss: 1.1161 - accuracy: 0.9988 - val_loss: 2.9089 - val_accuracy: 0.5783 - lr: 8.0000e-06
# Epoch 24/25
# 27/27 [==============================] - 92s 3s/step - loss: 1.1152 - accuracy: 0.9988 - val_loss: 2.9088 - val_accuracy: 0.5783 - lr: 8.0000e-06
# Epoch 25/25
# 27/27 [==============================] - 95s 4s/step - loss: 1.1143 - accuracy: 0.9988 - val_loss: 2.9099 - val_accuracy: 0.5843 - lr: 8.0000e-06
# 6/6 [==============================] - 4s 680ms/step
# 6/6 [==============================] - 4s 714ms/step - loss: 2.9099 - accuracy: 0.5843
# 6/6 [==============================] - 5s 709ms/step
# Epoch 1/25
# 27/27 [==============================] - 163s 6s/step - loss: 12.5608 - accuracy: 0.1489 - val_loss: 4.1511 - val_accuracy: 0.3012 - lr: 0.0010
# Epoch 2/25
# 27/27 [==============================] - 155s 6s/step - loss: 3.7940 - accuracy: 0.3421 - val_loss: 4.0959 - val_accuracy: 0.2410 - lr: 0.0010
# Epoch 3/25
# 27/27 [==============================] - 153s 6s/step - loss: 3.3063 - accuracy: 0.4922 - val_loss: 3.2708 - val_accuracy: 0.5120 - lr: 0.0010
# Epoch 4/25
# 27/27 [==============================] - 155s 6s/step - loss: 2.8352 - accuracy: 0.5918 - val_loss: 2.9280 - val_accuracy: 0.6024 - lr: 0.0010
# Epoch 5/25
# 27/27 [==============================] - 153s 6s/step - loss: 2.4195 - accuracy: 0.6975 - val_loss: 2.9265 - val_accuracy: 0.5904 - lr: 0.0010
# Epoch 6/25
# 27/27 [==============================] - 153s 6s/step - loss: 2.1129 - accuracy: 0.7911 - val_loss: 2.9705 - val_accuracy: 0.5120 - lr: 0.0010
# Epoch 7/25
# 27/27 [==============================] - 158s 6s/step - loss: 1.9494 - accuracy: 0.8199 - val_loss: 2.9976 - val_accuracy: 0.5783 - lr: 0.0010
# Epoch 8/25
# 27/27 [==============================] - 153s 6s/step - loss: 1.7112 - accuracy: 0.8860 - val_loss: 2.9725 - val_accuracy: 0.5904 - lr: 0.0010
# Epoch 9/25
# 27/27 [==============================] - 153s 6s/step - loss: 1.5466 - accuracy: 0.9316 - val_loss: 3.1690 - val_accuracy: 0.5843 - lr: 0.0010
# Epoch 10/25
# 27/27 [==============================] - 154s 6s/step - loss: 1.7637 - accuracy: 0.8439 - val_loss: 3.1044 - val_accuracy: 0.5482 - lr: 0.0010
# Epoch 11/25
# 27/27 [==============================] - 153s 6s/step - loss: 1.4955 - accuracy: 0.9424 - val_loss: 2.9296 - val_accuracy: 0.5723 - lr: 2.0000e-04
# Epoch 12/25
# 27/27 [==============================] - 157s 6s/step - loss: 1.3472 - accuracy: 0.9880 - val_loss: 3.0850 - val_accuracy: 0.6205 - lr: 2.0000e-04
# Epoch 13/25
# 27/27 [==============================] - 156s 6s/step - loss: 1.3178 - accuracy: 0.9856 - val_loss: 3.1182 - val_accuracy: 0.5904 - lr: 2.0000e-04
# Epoch 14/25
# 27/27 [==============================] - 152s 6s/step - loss: 1.2674 - accuracy: 0.9988 - val_loss: 3.1888 - val_accuracy: 0.6205 - lr: 2.0000e-04
# Epoch 15/25
# 27/27 [==============================] - 153s 6s/step - loss: 1.2395 - accuracy: 0.9976 - val_loss: 3.2760 - val_accuracy: 0.5964 - lr: 2.0000e-04
# Epoch 16/25
# 27/27 [==============================] - 152s 6s/step - loss: 1.2216 - accuracy: 0.9988 - val_loss: 3.2686 - val_accuracy: 0.6024 - lr: 4.0000e-05
# Epoch 17/25
# 27/27 [==============================] - 153s 6s/step - loss: 1.2170 - accuracy: 0.9988 - val_loss: 3.2801 - val_accuracy: 0.6084 - lr: 4.0000e-05
# Epoch 18/25
# 27/27 [==============================] - 155s 6s/step - loss: 1.2125 - accuracy: 0.9988 - val_loss: 3.3014 - val_accuracy: 0.6084 - lr: 4.0000e-05
# Epoch 19/25
# 27/27 [==============================] - 155s 6s/step - loss: 1.2078 - accuracy: 0.9988 - val_loss: 3.3189 - val_accuracy: 0.6084 - lr: 4.0000e-05
# Epoch 20/25
# 27/27 [==============================] - 153s 6s/step - loss: 1.2032 - accuracy: 0.9988 - val_loss: 3.3314 - val_accuracy: 0.6084 - lr: 4.0000e-05
# Epoch 21/25
# 27/27 [==============================] - 153s 6s/step - loss: 1.2002 - accuracy: 0.9988 - val_loss: 3.3335 - val_accuracy: 0.6084 - lr: 8.0000e-06
# Epoch 22/25
# 27/27 [==============================] - 152s 6s/step - loss: 1.1993 - accuracy: 0.9988 - val_loss: 3.3351 - val_accuracy: 0.6084 - lr: 8.0000e-06
# Epoch 23/25
# 27/27 [==============================] - 156s 6s/step - loss: 1.1983 - accuracy: 0.9988 - val_loss: 3.3377 - val_accuracy: 0.6084 - lr: 8.0000e-06
# Epoch 24/25
# 27/27 [==============================] - 155s 6s/step - loss: 1.1973 - accuracy: 0.9988 - val_loss: 3.3415 - val_accuracy: 0.6084 - lr: 8.0000e-06
# Epoch 25/25
# 27/27 [==============================] - 155s 6s/step - loss: 1.1963 - accuracy: 0.9988 - val_loss: 3.3428 - val_accuracy: 0.6084 - lr: 8.0000e-06
# 6/6 [==============================] - 6s 971ms/step
# 6/6 [==============================] - 6s 1s/step - loss: 3.3428 - accuracy: 0.6084
# 6/6 [==============================] - 7s 1s/step
# Epoch 1/25
# 27/27 [==============================] - 159s 6s/step - loss: 16.9062 - accuracy: 0.1537 - val_loss: 4.0986 - val_accuracy: 0.2590 - lr: 0.0010
# Epoch 2/25
# 27/27 [==============================] - 152s 6s/step - loss: 3.7902 - accuracy: 0.3061 - val_loss: 3.6478 - val_accuracy: 0.3012 - lr: 0.0010
# Epoch 3/25
# 27/27 [==============================] - 153s 6s/step - loss: 3.2354 - accuracy: 0.4538 - val_loss: 3.5689 - val_accuracy: 0.3494 - lr: 0.0010
# Epoch 4/25
# 27/27 [==============================] - 153s 6s/step - loss: 3.0393 - accuracy: 0.5078 - val_loss: 4.4371 - val_accuracy: 0.3373 - lr: 0.0010
# Epoch 5/25
# 27/27 [==============================] - 157s 6s/step - loss: 3.2259 - accuracy: 0.4514 - val_loss: 4.8018 - val_accuracy: 0.2711 - lr: 0.0010
# Epoch 6/25
# 27/27 [==============================] - 152s 6s/step - loss: 2.7963 - accuracy: 0.5618 - val_loss: 3.0587 - val_accuracy: 0.5181 - lr: 0.0010
# Epoch 7/25
# 27/27 [==============================] - 147s 5s/step - loss: 2.7200 - accuracy: 0.5798 - val_loss: 3.0007 - val_accuracy: 0.4759 - lr: 0.0010
# Epoch 8/25
# 27/27 [==============================] - 147s 5s/step - loss: 2.5244 - accuracy: 0.6194 - val_loss: 3.0544 - val_accuracy: 0.4578 - lr: 0.0010
# Epoch 9/25
# 27/27 [==============================] - 146s 5s/step - loss: 2.3607 - accuracy: 0.6735 - val_loss: 2.9231 - val_accuracy: 0.5181 - lr: 0.0010
# Epoch 10/25
# 27/27 [==============================] - 149s 6s/step - loss: 2.0821 - accuracy: 0.7371 - val_loss: 3.1916 - val_accuracy: 0.5241 - lr: 0.0010
# Epoch 11/25
# 27/27 [==============================] - 149s 6s/step - loss: 2.1410 - accuracy: 0.7155 - val_loss: 3.2904 - val_accuracy: 0.4940 - lr: 0.0010
# Epoch 12/25
# 27/27 [==============================] - 148s 5s/step - loss: 1.8316 - accuracy: 0.8079 - val_loss: 2.9846 - val_accuracy: 0.5181 - lr: 0.0010
# Epoch 13/25
# 27/27 [==============================] - 147s 5s/step - loss: 1.6882 - accuracy: 0.8547 - val_loss: 3.0046 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 14/25
# 27/27 [==============================] - 146s 5s/step - loss: 1.6596 - accuracy: 0.8643 - val_loss: 3.0451 - val_accuracy: 0.5542 - lr: 0.0010
# Epoch 15/25
# 27/27 [==============================] - 147s 5s/step - loss: 1.4202 - accuracy: 0.9580 - val_loss: 3.0680 - val_accuracy: 0.5843 - lr: 2.0000e-04
# Epoch 16/25
# 27/27 [==============================] - 148s 5s/step - loss: 1.3392 - accuracy: 0.9796 - val_loss: 3.0991 - val_accuracy: 0.5843 - lr: 2.0000e-04
# Epoch 17/25
# 27/27 [==============================] - 152s 6s/step - loss: 1.2910 - accuracy: 0.9928 - val_loss: 3.1936 - val_accuracy: 0.5783 - lr: 2.0000e-04
# Epoch 18/25
# 27/27 [==============================] - 149s 6s/step - loss: 1.2506 - accuracy: 0.9964 - val_loss: 3.2806 - val_accuracy: 0.5964 - lr: 2.0000e-04
# Epoch 19/25
# 27/27 [==============================] - 149s 6s/step - loss: 1.2176 - accuracy: 0.9988 - val_loss: 3.3290 - val_accuracy: 0.5964 - lr: 2.0000e-04
# Epoch 20/25
# 27/27 [==============================] - 147s 5s/step - loss: 1.1973 - accuracy: 1.0000 - val_loss: 3.3229 - val_accuracy: 0.5904 - lr: 4.0000e-05
# Epoch 21/25
# 27/27 [==============================] - 147s 5s/step - loss: 1.1903 - accuracy: 1.0000 - val_loss: 3.3484 - val_accuracy: 0.5783 - lr: 4.0000e-05
# Epoch 22/25
# 27/27 [==============================] - 149s 6s/step - loss: 1.1850 - accuracy: 1.0000 - val_loss: 3.3643 - val_accuracy: 0.5843 - lr: 4.0000e-05
# Epoch 23/25
# 27/27 [==============================] - 150s 6s/step - loss: 1.1803 - accuracy: 1.0000 - val_loss: 3.3730 - val_accuracy: 0.5843 - lr: 4.0000e-05
# Epoch 24/25
# 27/27 [==============================] - 153s 6s/step - loss: 1.1751 - accuracy: 1.0000 - val_loss: 3.3837 - val_accuracy: 0.5964 - lr: 4.0000e-05
# Epoch 25/25
# 27/27 [==============================] - 149s 6s/step - loss: 1.1716 - accuracy: 1.0000 - val_loss: 3.3855 - val_accuracy: 0.5843 - lr: 8.0000e-06
# 6/6 [==============================] - 7s 1s/step
# 6/6 [==============================] - 7s 1s/step - loss: 3.3855 - accuracy: 0.5843
# Max validation accuracy using cross-validation on the best model: 0.652694582939148

# %%
# Use mean_average_scores to get the total importance of each token for each sample
total_importance = np.sum(mean_average_scores, axis=1)

# %%
best_model_full = create_model(sequence_length, spectrogram_height, spectrogram_width, latent_dim, num_classes, num_attention_heads)
best_model_full.set_weights(best_model_weights)

# %%
best_model_full.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
best_model = tf.keras.models.Model(inputs=best_model_full.input, outputs=best_model_full.output[0])
best_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
train_loss, train_accuracy = best_model.evaluate(X_train, y_train)
print("Total Loss:", train_loss)
print(f"Total Accuracy: {train_accuracy * 100:.2f}%")
# Out:
# 32/32 [==============================] - 38s 1s/step - loss: 1.4105 - accuracy: 0.9409
# Total Loss: 1.410517692565918
# Total Accuracy: 94.09%

# %%
# Check accuracy on the test set
test_loss, test_accuracy = best_model.evaluate(X_test, y_test)
print("Test Loss:", test_loss)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# %% [markdown]
# ## Analysis

# %%
new_genre_labels = {
    0: 'blues',
    1: 'classical',
    2: 'country',
    3: 'disco',
    4: 'hiphop',
    5: 'jazz',
    6: 'metal',
    7: 'pop',
    8: 'reggae',
    9: 'rock'
}

# %% [markdown]
# ###  Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
y_pred = np.argmax(best_model.predict(X_train), axis=1)
conf_matrix = confusion_matrix(y_train, y_pred)
# Out:
# 32/32 [==============================] - 34s 1s/step

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False, 
            xticklabels=new_genre_labels.values(), yticklabels=new_genre_labels.values())
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ### PCA Analysis

# %%
# !python -m pip install --upgrade scikit-learn seaborn networkx
# Out:
# Requirement already satisfied: scikit-learn in e:\aditya\python\lib\site-packages (1.3.2)
# Requirement already satisfied: seaborn in e:\aditya\python\lib\site-packages (0.13.2)
# Requirement already satisfied: networkx in e:\aditya\python\lib\site-packages (3.1)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in e:\aditya\python\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in e:\aditya\python\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in e:\aditya\python\lib\site-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in e:\aditya\python\lib\site-packages (from scikit-learn) (3.4.0)
# Requirement already satisfied: pandas>=1.2 in e:\aditya\python\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in e:\aditya\python\lib\site-packages (from seaborn) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in e:\aditya\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in e:\aditya\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\aditya\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\aditya\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\adity\appdata\roaming\python\python38\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in e:\aditya\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\aditya\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\adity\appdata\roaming\python\python38\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in e:\aditya\python\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in e:\aditya\python\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in e:\aditya\python\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\adity\appdata\roaming\python\python38\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\adity\appdata\roaming\python\python38\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import numpy as np

num_samples = X_train.shape[0]
sequence_length = X_train.shape[1]
spectrogram_height = X_train.shape[2]
spectrogram_width = X_train.shape[3]

# Reshape X_train to (total_images, height, width, channels)
X_train_reshaped = X_train.reshape(num_samples * sequence_length, spectrogram_height, spectrogram_width, 1)

# Extract cnn_model from best_model
cnn_model = best_model.layers[1].layer  # Accessing the cnn_model within the TimeDistributed layer

# Get outputs of cnn_model on X_train
cnn_outputs = cnn_model.predict(X_train_reshaped)
# Out:
# 625/625 [==============================] - 36s 57ms/step

# %%
# Reshape cnn_outputs to match the original shape of X_train
cnn_outputs_reshaped = cnn_outputs.reshape(num_samples, sequence_length, -1)

# Average the CNN outputs for every 20 samples
averaged_cnn_outputs = np.mean(cnn_outputs_reshaped, axis=1)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca_result_2d = pca.fit_transform(averaged_cnn_outputs)

print("Shape of PCA result:", pca_result_2d.shape)
# Out:
# Shape of PCA result: (999, 2)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
pca_result_3d = pca.fit_transform(averaged_cnn_outputs)

print("Shape of PCA result:", pca_result_3d.shape)
# Out:
# Shape of PCA result: (999, 3)

# %%
genre_colors = {
    0: 'blue',
    1: 'green',
    2: 'red',
    3: 'cyan',
    4: 'magenta',
    5: 'yellow',
    6: 'black',
    7: 'brown',
    8: 'orange',
    9: 'purple'
}

# %%
# Compute the mean of PCA-transformed coordinates for each genre
import matplotlib.pyplot as plt
genre_means_2d = np.zeros((len(new_genre_labels), 2))  # Initialize array to store means
for genre_label, color in new_genre_labels.items():
    genre_indices = np.where(y_train == genre_label)[0]
    genre_mean = np.mean(pca_result_2d[genre_indices], axis=0)
    genre_means_2d[genre_label] = genre_mean

# Create a scatter plot for mean coordinates with colors based on genre labels
plt.figure(figsize=(10, 10))
for genre_label, color in genre_colors.items():
    plt.scatter(genre_means_2d[genre_label, 0], genre_means_2d[genre_label, 1], color=color, label=f'{new_genre_labels[genre_label]}')

plt.title('Mean PCA plot of genres (2D)')
plt.xlabel('PCA Dimension 1')
plt.ylabel('PCA Dimension 2')
plt.legend(title='Genre')
plt.grid(True)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt 

# Create a 3D scatter plot for PCA-transformed coordinates with colors based on genre labels
fig = plt.figure(figsize=(20, 20))
ax = fig.add_subplot(111, projection='3d')
for genre_label, color in genre_colors.items():
    genre_indices = np.where(y_train == genre_label)[0]
    ax.scatter(pca_result_3d[genre_indices, 0], pca_result_3d[genre_indices, 1], pca_result_3d[genre_indices, 2], color=color, label=f'{new_genre_labels[genre_label]}')

ax.set_title('PCA plot of images colored by genre')
ax.set_xlabel('PCA Dimension 1')
ax.set_ylabel('PCA Dimension 2')
ax.set_zlabel('PCA Dimension 3')
ax.legend(title='Genre')
plt.show()

# %%
genre_means = np.zeros((len(new_genre_labels), 3))  # Initialize array to store means
for genre_label, color in new_genre_labels.items():
    genre_indices = np.where(y_train == genre_label)[0]
    genre_mean = np.mean(pca_result_3d[genre_indices], axis=0)
    genre_means[genre_label] = genre_mean

# %%
# Create a 3D scatter plot for mean coordinates with colors based on genre labels
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
for genre_label, color in genre_colors.items():
    ax.scatter(genre_means[genre_label, 0], genre_means[genre_label, 1], genre_means[genre_label, 2], color=color, label=new_genre_labels[genre_label])

ax.set_title('Mean PCA plot of genres')
ax.set_xlabel('PCA Dimension 1')
ax.set_ylabel('PCA Dimension 2')
ax.set_zlabel('PCA Dimension 3')
ax.legend(title='Genre')
plt.show()

# %%
threshold = 4.5

# Check combinations of genres
num_genres = len(genre_means)
found_combinations = []
checked_combinations = set()

for i in range(num_genres):
    for j in range(num_genres):
        for k in range(num_genres):
            if i != j != k:  # Ensure A, B, C are different genres
                A = genre_means[i]
                B = genre_means[j]
                C = genre_means[k]

                # Find D such that A - B + C = D
                D = A - B + C

                # Check if D vector is close to any other genre vector
                for m in range(num_genres):
                    if m != i != j != k:
                        if m not in (i, j, k):  # Ensure D is not one of A, B, C
                            if np.allclose(D, genre_means[m], atol=threshold):
                                # Sort and store the combination as a tuple to avoid duplicates
                                sorted_combination = tuple(sorted([i, j, k, m]))
                                if sorted_combination not in checked_combinations:
                                    checked_combinations.add(sorted_combination)
                                    found_combinations.append((i, j, k, m))

# Print the found combinations
print("Based on the PCA plot, the following equations were found:")
for i, combination in enumerate(found_combinations):
    genre_A, genre_B, genre_C, genre_D = combination
    print(f"{i + 1}. {new_genre_labels[genre_A]} - {new_genre_labels[genre_B]} + {new_genre_labels[genre_C]} = {new_genre_labels[genre_D]}")
# Out:
# Based on the PCA plot, the following equations were found:
# 1. blues - country + disco = rock
# 2. blues - country + hiphop = reggae
# 3. country - reggae + hiphop = rock
# 4. disco - metal + disco = pop
# 5. disco - metal + rock = pop
# 6. disco - pop + hiphop = rock
# 7. hiphop - metal + rock = reggae

# %%
# Find the two closest genres to a given genre
def find_closest_genres(genre_means, genre_label, num_closest=2):
    genre_mean = genre_means[genre_label]
    distances = np.linalg.norm(genre_means - genre_mean, axis=1)
    closest_genres = np.argsort(distances)[1:num_closest + 1]
    return closest_genres

# %%
# Find the closest two genres to each genre
closest_dict = {}
for genre_label, genre_name in new_genre_labels.items():
    closest_genres = find_closest_genres(genre_means, genre_label)
    closest_genre_names = [new_genre_labels[closest_genre] for closest_genre in closest_genres]
    closest_dict[genre_name] = [closest_genre_names[0], closest_genre_names[1]]
    print(f"The closest genres to {genre_name} are {closest_genre_names[0]} and {closest_genre_names[1]}")
# Out:
# The closest genres to blues are country and reggae
# The closest genres to classical are jazz and blues
# The closest genres to country are blues and reggae
# The closest genres to disco are rock and hiphop
# The closest genres to hiphop are reggae and pop
# The closest genres to jazz are classical and blues
# The closest genres to metal are rock and disco
# The closest genres to pop are hiphop and reggae
# The closest genres to reggae are hiphop and pop
# The closest genres to rock are disco and hiphop

# %%
import networkx as nx
import matplotlib.pyplot as plt

genres = ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
closest_genres = [closest_dict[genre] for genre in genres]

G = nx.Graph()
G.add_nodes_from(genres)

for i, genre in enumerate(genres):
    closest = closest_genres[i]
    G.add_edges_from([(genre, closest[0]), (genre, closest[1])])
pos = nx.spring_layout(G)
plt.figure(figsize=(10, 10))
nx.draw_networkx(G, pos, with_labels=True, node_color='lightblue', edge_color='black', font_size=6, node_size=1200)

# Add a title
plt.title('Closest Genres')
plt.show()

# %% [markdown]
# ### Attention Weights Analysis

# %%
classification_outputs, attention_scores = best_model_full.predict(X_train)
mean_attention_scores = np.mean(attention_scores, axis=1)
most_important_tokens = np.argmax(mean_attention_scores, axis=1)
total_importance = np.sum(mean_attention_scores, axis=1)
# Out:
# 32/32 [==============================] - 35s 1s/step

# %%
# For each sample, max count of most important token is the sample most important token
from collections import Counter
most_important_tokens_per_sample = np.array([Counter(tokens).most_common(1)[0][0] for tokens in most_important_tokens])

# %%
for i, token_idx in enumerate(most_important_tokens):
        print(f"Sample {i}: Most important token is at index {token_idx}")
        if i > 0:
            break
# Out:
# Sample 0: Most important token is at index [11  9 11 11  9 11 15 15 11 11 11 11 15 15  7 11  8 16 16 15]
# Sample 1: Most important token is at index [ 0 12 12 12 12 12 12 13 12 13 13 12 12  0 12 12 12 12 12 13]

# %%
# Add total_importance of samples of the same genre. Output shape should be (num_genres, sequence_length)
genre_importance = np.zeros((num_classes, sequence_length))
for genre_label in range(num_classes):
    genre_indices = np.where(y_train == genre_label)[0]
    genre_total_importance = np.sum(total_importance[genre_indices], axis=0)
    genre_importance[genre_label] = genre_total_importance

# %%
# Plot softmax of genre_importance for each genre
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
for genre_label, genre_name in new_genre_labels.items():
    plt.plot(genre_importance[genre_label], label=genre_name)

plt.title('Total Importance of Tokens for each Genre')
plt.xlabel('Token Index')
plt.ylabel('Total Importance')
plt.legend(title='Genre')
plt.grid(True)
plt.show()

# %%
# Find the 5 most important tokens for each genre
most_important_tokens_per_genre = np.argsort(genre_importance, axis=1)[:, -4:]

# Print the 5 most important tokens for each genre
for genre_label, genre_name in new_genre_labels.items():
    print(f"{genre_name}: {most_important_tokens_per_genre[genre_label]}")
# Out:
# blues: [12  1 11  0]
# classical: [13 17  6  0]
# country: [ 6 12 11  7]
# disco: [16  2 15 11]
# hiphop: [ 2  0 19 10]
# jazz: [17  0 19 11]
# metal: [16  1 11  0]
# pop: [ 7 15  0 11]
# reggae: [ 9  2 13 19]
# rock: [19 12 11  0]

# %%
# Find the overall most important tokens acrosss all genres
total_importance = np.sum(genre_importance, axis=0)
most_important_tokens_overall = np.argsort(total_importance)[-5:]
print("Overall most important tokens:", most_important_tokens_overall)
# Out:
# Overall most important tokens: [ 1 19  2  0 11]

# %%
classification_outputs, attention_scores = best_model_full.predict(X_train)
mean_attention_scores = np.mean(attention_scores, axis=1)
most_important_tokens = np.argmax(mean_attention_scores, axis=1)
total_importance = np.sum(mean_attention_scores, axis=1)
# Out:
# 32/32 [==============================] - 27s 814ms/step

# %%
# Choose 3 random samples from each genre and plot the attention scores - use total_importance
import matplotlib.pyplot as plt
import seaborn as sns
import random

num_samples_per_genre = 5
plt.figure(figsize=(20, 20))
for genre_label, genre_name in new_genre_labels.items():
    genre_indices = np.where(y_train == genre_label)[0]
    random_sample_indices = random.sample(list(genre_indices), num_samples_per_genre)
    for i, sample_idx in enumerate(random_sample_indices):
        plt.subplot(num_classes, num_samples_per_genre, genre_label * num_samples_per_genre + i + 1)
        # plot softmax(total_importance) for each sample
        plt.plot([np.exp(score)/np.sum(np.exp(total_importance[sample_idx])) for score in total_importance[sample_idx]])  
        plt.title(f"{genre_name} - Sample number in genre: {sample_idx % 100}")
        plt.xlabel('Token Index')
        plt.ylabel('Attention Score')
        # Also print the three most important tokens for each sample inside the plot
        most_important_tokens = np.argsort(total_importance[sample_idx])[-3:]
        plt.text(0.5, 0.5, f"Top 3 tokens: {most_important_tokens}", horizontalalignment='right', verticalalignment='top', transform=plt.gca().transAxes)

plt.tight_layout()
plt.show()

# %%
# For each token, print the seconds it signifies - 0: 0-1.95s, 1: 1.5-3.45s, 2: 3-4.95s and so on
for i in range(20):
    print(f"Token {i}: {i * 4.48 * 0.3:.2f}s to {((i * 4.48 * 0.3) + 4.48):.2f}s")
# Out:
# Token 0: 0.00s to 4.48s
# Token 1: 1.34s to 5.82s
# Token 2: 2.69s to 7.17s
# Token 3: 4.03s to 8.51s
# Token 4: 5.38s to 9.86s
# Token 5: 6.72s to 11.20s
# Token 6: 8.06s to 12.54s
# Token 7: 9.41s to 13.89s
# Token 8: 10.75s to 15.23s
# Token 9: 12.10s to 16.58s
# Token 10: 13.44s to 17.92s
# Token 11: 14.78s to 19.26s
# Token 12: 16.13s to 20.61s
# Token 13: 17.47s to 21.95s
# Token 14: 18.82s to 23.30s
# Token 15: 20.16s to 24.64s
# Token 16: 21.50s to 25.98s
# Token 17: 22.85s to 27.33s
# Token 18: 24.19s to 28.67s
# Token 19: 25.54s to 30.02s

# %% [markdown]
# Observations:
# 1. Blues - The important timesteps seem to be portions/ freuencies that are "abnormal, out of scale, and different from the rest". Also, wherever there are signficant "pauses" in the music - that seems to be characteristic of Blues. The guitars play a significant role, whenever the guitars play characteristic Blues licks, the model seems to catch on to it.
# 2. Classical - Grandeur: When the cymbals come in, the strings and the horns - a magnum opus of the orchestra. That's what it picks up on. Sustenance of notes - when a note plays for a long time, it is very much used particularly in classical music to build up the next "act". Repetition - when the same "phrase" is repeated a few times over the piece, it is significant to the genre.
# 3. Country - Higher Frequencies (rarity).
#
# 4. Disco - Build Ups. Also, alternate tokens are important, maybe due to the "up and down" nature of Disco genre. You see lots of peaks all adjacent to troughs then peak again in a repetitive fashion. Powerful vocals
